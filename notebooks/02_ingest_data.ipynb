# %% [markdown]
# ### Ingest data into OpenSearch
# - Clean up text
# - Split text into chunks
# - Format text for OpenSearch

# %%
import re
import os
import ocrmypdf
from pathlib import Path
import pymupdf
import torch
import spacy
from tqdm.auto import tqdm
import sys

import json
import urllib.parse
import hashlib
import itertools

from opensearchpy import OpenSearch, helpers

sys.path.append('../src')

from utils import *
from config import *

# %%
# Run on GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Running code @ {device}')
# Out:
# Running code @ cpu

# %% [markdown]
# Load spaCy language model for Romanian

# %%
# load the pre-trained spacy language model "ro_core_news_lg"
nlp = spacy.load("ro_core_news_lg")

# %% [markdown]
# ##### Clean up text

# %%
def cleanup_text(text: str) -> str:
    # remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # # convert to lowercase
    # text = text.lower()

    # clean up table of contents 
    text = re.sub(r'\.{4,}\s*\d+', '', text).strip()

    return text

# %% [markdown]
# #### Parse PDF

# %%
def parse_pdf(pdf_path: str, url: str) -> dict:
    assert os.path.exists(pdf_path), f'Path {pdf_path} not found'

    # decode percent-encoded/URL-encoded filename -> get diacritics
    filename = urllib.parse.unquote(pdf_path.split('/')[-1])

    document = pymupdf.open(pdf_path, filetype="pdf")
    data = {
        "filename": filename,
        "path": pdf_path,
        "url": url,
        "sentences": [],
    }

    for page_number, page in enumerate(document):
        text = cleanup_text(page.get_text())

        doc = nlp(text)

        data["sentences"].extend([
            {
                "page_number": page_number + 1,
                "text": str(sentence)
            }
            for sentence in doc.sents
        ])
    
    return data

# %% [markdown]
# #### Split text into chunks

# %%
def split_text_into_chunks(data: dict, max_length: int = 1024) -> dict:
    paragraphs = []

    current_paragraph = []
    page_number = 1
    length = 0
    chunk_number = 1

    for sentence in data["sentences"]:
        if length + len(sentence["text"]) > max_length:
            paragraphs.append({
                "id": get_id(data["url"], chunk_number),
                "text": " ".join(current_paragraph),
                "url": data["url"],
                "type": "pdf",
                "filename": data["filename"],
                "page_number": page_number,
            })
            current_paragraph.clear()
            page_number = sentence["page_number"]
            length = 0
            chunk_number += 1
        
        current_paragraph.append(sentence["text"])
        length += len(sentence["text"])
    
    if current_paragraph:
        paragraphs.append({
            "id": get_id(data["url"], chunk_number),
            "text": " ".join(current_paragraph),
            "url": data["url"],
            "type": "pdf",
            "filename": data["filename"],
            "page_number": page_number,
        })

    return paragraphs

# %% [markdown]
# #### Ingest data into OpenSearch

# %%
ADMIN_PASSWD = os.environ['OPENSEARCH_INITIAL_ADMIN_PASSWORD']
INDEX_NAME = 'rag-knn-index'
MODEL_ID = ''

# %%
host = 'localhost'
port = 9200

# Create the client with SSL/TLS and hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': host, 'port': port}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = ('admin', ADMIN_PASSWD),
    use_ssl = True,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
)

print(json.dumps(client.info(), indent=4))
# Out:
# {
#     "name": "opensearch-node1",
#     "cluster_name": "opensearch-cluster",
#     "cluster_uuid": "exKC0fQ7Tomx9X3wA4fBbA",
#     "version": {
#         "distribution": "opensearch",
#         "number": "2.19.1",
#         "build_type": "tar",
#         "build_hash": "2e4741fb45d1b150aaeeadf66d41445b23ff5982",
#         "build_date": "2025-02-27T01:16:47.726162386Z",
#         "build_snapshot": false,
#         "lucene_version": "9.12.1",
#         "minimum_wire_compatibility_version": "7.10.0",
#         "minimum_index_compatibility_version": "7.0.0"
#     },
#     "tagline": "The OpenSearch Project: https://opensearch.org/"
# }

# %% [markdown]
# #### Format data for OpenSearch index

# %%
def format_data(paragraphs: dict[str, str]) -> dict[str, str]:
    return [
        {"_index": INDEX_NAME, "_id": paragraph["id"]} | paragraph
        for paragraph in paragraphs
    ]

# %%
def ingest_data(path=DATA_DIR) -> None:
    directories = get_directories(path)
    directories.remove(OCR_DIR.name)

    for directory in directories:
        pdfs = get_files_by_extension(path=os.path.join(DATA_DIR, directory), extension=".pdf")

        metadata_filepath = Path(path) / directory / "metadata.json"
        metadata = read_metadata(metadata_filepath)

        for filename in pdfs:
            pdf_path = DATA_DIR / directory / filename
            if "ocr_path" in metadata[filename]:
                pdf_path = BASE_DIR / metadata[filename]["ocr_path"]

            data = parse_pdf(pdf_path=pdf_path.as_posix(), url=metadata[filename]["url"])

            paragraphs = split_text_into_chunks(data)
            # for paragraph in paragraphs[:10]:
            #     print(paragraph)

            entries = format_data(paragraphs)
            # print(entries)

            ret = helpers.parallel_bulk(
                client, 
                actions=entries, 
                chunk_size=10, 
                raise_on_error=False,
                raise_on_exception=False,
                max_chunk_bytes=20 * 1024 * 1024,
                request_timeout=60
            )

            print(list(ret))
            
ingest_data()
# Out:
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 0, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 3, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 4, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 6, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 9, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 11, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 13, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 15, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 17, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 18, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 1, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 2, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 7, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'fab2ac7fe58ff17b51af9bdd7be38904e3a4f541961db7da0259d45ceebee82e-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 8, '_primary_term': 1, 'status': 201}}), (True, {'inde ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 20, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 21, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 22, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 23, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 24, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 25, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 26, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 27, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 28, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 29, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '12c079b3f0d9cb7be2e74e328988157c1e816fe8cdd059174680ff4ce6b41f13-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 19, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 50, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 51, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 53, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 54, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 56, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 57, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 59, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 61, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 62, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 64, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 52, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 55, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 58, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 60, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'a98a700ef6b47f46f4820a8597f1e9f15e10b6ff2acf9ea891b73ec6c83fabb0-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 63, '_primary_term': 1, 'status': 201}}), (Tr ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 166, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 167, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 168, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 169, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 170, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 171, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 172, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 173, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 174, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 175, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 177, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 179, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 181, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 184, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '7c575108846abc52091ee31522317fc9f33cabec49d1ce011311cd1e302e710a-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 187, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 225, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 226, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 227, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 228, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 229, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 230, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 231, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 232, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 233, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 234, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 205, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 206, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 207, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 208, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ca7c28dfef03f780efd1a4563811305eccf2dabc62973c30605be8e73669e1ea-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 209, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 259, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 260, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 261, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 262, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 263, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 264, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 265, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 266, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 267, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 268, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 249, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 250, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 251, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 252, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'aa2b8f0341ce68181e454d88b10fa2c090716cd2b4bc3f584ef82d14edb44628-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 253, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 299, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 300, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 301, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 302, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 303, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 304, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 305, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 306, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 307, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 308, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 279, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 280, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 281, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 282, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'f617d216defe58d49ad791a8184fd6b1ddcdc2e566e7488d608b1598733afcac-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 283, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 336, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 337, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 338, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 339, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 340, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 341, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 342, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 343, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 344, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 345, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 346, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 347, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 348, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 349, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'b02cf211372bd5c92cf1ad8662b9be3e438423925184c6d756a97cd13e4ce122-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 350, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 356, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 357, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 358, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 359, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 360, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 361, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 362, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 363, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 364, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 365, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 386, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 387, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 388, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 389, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ddcead7f211bc03956b90d2b3aec51899c45c697734845eecdb3f2530abac70e-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 390, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 561, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 562, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 563, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 564, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 565, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 566, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 567, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd1a41d50ae1d36a803d7f09b34743409cdc47c75cb3bdfa34586f1aae394509b-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 568, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 590, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 592, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 594, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 596, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 598, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 600, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 601, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 602, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 603, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 604, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 585, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 586, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 587, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 588, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9f87db460ff0f117a2ab0bfc1df9fbd4857192f9d8c696b79d1264ed5911eef3-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 589, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 605, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 606, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 607, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 608, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 609, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 610, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 611, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 612, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 613, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 614, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 623, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 624, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 625, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 626, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '13142db07b80735c2a79d1026f2bd9a26ecf200c6e4db77ca68b60fecef5875e-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 627, '_primary_term': 1, 'statu ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '6c849d0a5c0c5243ed30034a7912118e0e3cfc6c49f13128d14f44976e1ccc4d-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 633, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '6c849d0a5c0c5243ed30034a7912118e0e3cfc6c49f13128d14f44976e1ccc4d-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 634, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '6c849d0a5c0c5243ed30034a7912118e0e3cfc6c49f13128d14f44976e1ccc4d-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 635, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '6c849d0a5c0c5243ed30034a7912118e0e3cfc6c49f13128d14f44976e1ccc4d-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 636, '_primary_term': 1, 'status': 201}})]
# ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5332, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5333, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5334, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5335, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5336, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5337, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5338, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'd2a676e8c492063c5c58ae0d413cab08996da252543be92b0c88f36fdc111ec1-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5339, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '9e61e56266c19cf13974c33acf8b45c213de41ea0ab48778ce18cc6c0aedb7f0-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5340, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9e61e56266c19cf13974c33acf8b45c213de41ea0ab48778ce18cc6c0aedb7f0-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5341, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9e61e56266c19cf13974c33acf8b45c213de41ea0ab48778ce18cc6c0aedb7f0-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5342, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '9e61e56266c19cf13974c33acf8b45c213de41ea0ab48778ce18cc6c0aedb7f0-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5343, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'e055403e3d649a1ce8d5434da2702e10a176e0e3b05860caec860c30f681db27-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5344, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'e055403e3d649a1ce8d5434da2702e10a176e0e3b05860caec860c30f681db27-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5345, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'e055403e3d649a1ce8d5434da2702e10a176e0e3b05860caec860c30f681db27-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5346, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'e055403e3d649a1ce8d5434da2702e10a176e0e3b05860caec860c30f681db27-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5347, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5368, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5369, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5370, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5371, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5372, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5373, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5374, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5375, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5376, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5377, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5348, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5349, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5350, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5351, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '256844ff770527b26eb286274b2031426996840a95fb4b3a1e73658b9f95c264-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5352, '_primary_t ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '42765d9158a612840a83cb3a357fa1e765cfda3a321ea3f7557470afc8031a2b-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5397, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '93fc4a5a3c621f0d14f4093bedf6d907ced61f6327fcc9aa6949d7b871099a64-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5398, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': '93fc4a5a3c621f0d14f4093bedf6d907ced61f6327fcc9aa6949d7b871099a64-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5399, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5400, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5401, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5402, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5403, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5404, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5405, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5406, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5407, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5408, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5409, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5410, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5411, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5412, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5413, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'c23065351e3dd83347e0359715a3862b308804675790261c154ef88f0976e52f-15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5414, '_primary_t ...
# [(True, {'index': {'_index': 'rag-knn-index', '_id': 'ff326f89730be51f8233de64a398c43b29241618bb57851d93d3257444faa388-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5857, '_primary_term': 1, 'status': 201}}), (True, {'index': {'_index': 'rag-knn-index', '_id': 'ff326f89730be51f8233de64a398c43b29241618bb57851d93d3257444faa388-2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5858, '_primary_term': 1, 'status': 201}})]
# [(True, {'index': {'_index': 'rag-knn-index', '_id': '5bf3bf7150d36bb29a51e19c01a0b0e30f0f7daee0c72bd78a577c7fe48bc457-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5859, '_primary_term': 1, 'status': 201}})]

# %% [markdown]
# ### Search data

# %%
query_text = "atributii responsabili de proces"

query = {
    "size": 3,
    "query": {
      "neural": {
        "passage_embedding": {
          "query_text": query_text,
          "model_id": MODEL_ID,
          "k": 3
        }
      }
  }
}

response = client.search(
    body = query,
    index = INDEX_NAME,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       1 query_text = "atributii responsabili de proces"
#       3 query = {
#       4     "size": 3,
#       5     "query": {
#       6       "neural": {
#       7         "passage_embedding": {
#       8           "query_text": query_text,
# ----> 9           "model_id": MODEL_ID,
#      10           "k": 3
#      11         }
#      12       }
#      13   }
#      14 }
#      16 response = client.search(
#      17     body = query,
#      18     index = INDEX_NAME,
#      19 )
#
# NameError: name 'MODEL_ID' is not defined
